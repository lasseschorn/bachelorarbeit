# %%
import os
import pandas as pd
import variablen as var

# %%
methode = var.methode_2

# %%
save_dir = var.result_dir + methode + "/"

# %%
mar_files = os.listdir(var.mar_dir)

# %%
mcar_files = os.listdir(var.mcar_dir)

# %%
mnar_files = os.listdir(var.mnar_dir)

# %%
def categorical_imputation(orginal_df):
    test_df = orginal_df[[var.column_name, "test"]]
    test_df = test_df.rename(columns={var.column_name: "orginal"})
    #Filling missing values with medians of the columns
    test_df['test'].fillna((test_df['test'].median()), inplace=True)
    return test_df

# %%
def execute(file,save_dir):
    df = pd.read_csv(file,  na_filter= False)
    result = categorical_imputation(df) 
    result.to_csv( save_dir  ,index=False)

# %%
for i in mar_files:
    execute(var.mar_dir + i, save_dir  + 'MAR/' + i )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-936157461e40> in <module>
# ----> 1 for i in mar_files:
#       2     execute(var.mar_dir + i, save_dir  + 'MAR/' + i )
#
# NameError: name 'mar_files' is not defined

# %%
for i in mcar_files:
    execute(var.mcar_dir + i, save_dir + 'MCAR/' + i )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      68                 with np.errstate(invalid="ignore"):
# ---> 69                     return f(*args, **kwargs)
#      70             except ValueError as e:
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     124             else:
# --> 125                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     126
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in nanmedian(values, axis, skipna, mask)
#     590     if not is_float_dtype(values):
# --> 591         values = values.astype("f8")
#     592         if mask is not None:
#
# ValueError: could not convert string to float:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-0f5ac3cedd82> in <module>
#       1 for i in mcar_files:
# ----> 2     execute(var.mcar_dir + i, save_dir + 'MCAR/' + i )
#
# <ipython-input-12-e18d4ec422a6> in execute(file, save_dir)
#       1 def execute(file,save_dir):
#       2     df = pd.read_csv(file,  na_filter= False)
# ----> 3     result = categorical_imputation(df)
#       4     result.to_csv( save_dir  ,index=False)
#
# <ipython-input-9-9cc9404a1d73> in categorical_imputation(orginal_df)
#       3     test_df = test_df.rename(columns={var.column_name: "orginal"})
#       4     #Filling missing values with medians of the columns
# ----> 5     test_df['test'].fillna((test_df['test'].median()), inplace=True)
#       6     return test_df
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11215             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11216         return self._reduce(
# > 11217             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11218         )
#   11219
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3889                 )
#    3890             with np.errstate(all="ignore"):
# -> 3891                 return op(delegate, skipna=skipna, **kwds)
#    3892
#    3893         # TODO(EA) dispatch to Index
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      74                 # object arrays that contain strings
#      75                 if is_object_dtype(args[0]):
# ---> 76                     raise TypeError(e)
#      77                 raise
#      78
#
# TypeError: could not convert string to float:

# %%
for i in mnar_files:
    execute(var.mnar_dir + i, save_dir + 'MNAR/' )
